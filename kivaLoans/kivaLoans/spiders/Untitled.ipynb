# %%
import os
os.chdir(r'/media/datngo/Driver1/Uni of Warsaw/2.6 Web Scraping and Social Media Scraping/Project/kivaLoans/kivaLoans/spiders')
URLdir = os.path.join(os.getcwd(),'../../../loanURLs.csv')
with open(URLdir, "rt") as f:
    try:
        starturls = [url.strip()+'?minimal=false' for url in f.readlines()]
# starturls = ['https://www.kiva.org/lend/392648?minimal=false']
    except:
        starturls = []
starturls
# Out:
# ['https://www.kiva.org/lend/1148004?minimal=false',
#  'https://www.kiva.org/lend/1148800?minimal=false',
#  'https://www.kiva.org/lend/888253?minimal=false',
#  'https://www.kiva.org/lend/756513?minimal=false',
#  'https://www.kiva.org/lend/992733?minimal=false',
#  'https://www.kiva.org/lend/725227?minimal=false',
#  'https://www.kiva.org/lend/507524?minimal=false',
#  'https://www.kiva.org/lend/561250?minimal=false',
#  'https://www.kiva.org/lend/729621?minimal=false',
#  'https://www.kiva.org/lend/681919?minimal=false',
#  'https://www.kiva.org/lend/933577?minimal=false',
#  'https://www.kiva.org/lend/724393?minimal=false',
#  'https://www.kiva.org/lend/743381?minimal=false',
#  'https://www.kiva.org/lend/808493?minimal=false',
#  'https://www.kiva.org/lend/1095926?minimal=false',
#  'https://www.kiva.org/lend/562146?minimal=false',
#  'https://www.kiva.org/lend/519357?minimal=false',
#  'https://www.kiva.org/lend/359395?minimal=false',
# ...

# %%
import re
re.sub("[^\d]",'','sacn1df3')
# Out:
# '13'

# %%
os.chdir(os.path.join(os.getcwd(),'../../../'))
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'attributes.csv',
#  'countries.csv',
#  'geckodriver.log',
#  'Kiva Project.ipynb',
#  'kivaLoans',
#  'Kiva_Database.ipynb',
#  'loanURLs.csv',
#  'project_Selenium.py',
#  'project_test.py',
#  'sectors.csv',
#  'url.csv']
